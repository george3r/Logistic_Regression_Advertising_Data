# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ad_data = pd.read_csv('advertising.csv')

# %%
ad_data
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
ad_data['Timestamp'] = pd.to_datetime(ad_data['Timestamp'])

# %%
ad_data['Year'] = pd.DatetimeIndex(ad_data['Timestamp']).year
ad_data['Month'] = pd.DatetimeIndex(ad_data['Timestamp']).month
ad_data['Day'] = pd.DatetimeIndex(ad_data['Timestamp']).day
ad_data['Time'] = pd.DatetimeIndex(ad_data['Timestamp']).time

# %%
ad_data
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
ad_data.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad    Year        Month  \
# count           1000.000000  1000.000000     1000.00000  1000.0  1000.000000
# mean             180.000100     0.481000        0.50000  2016.0     3.817000
# std               43.902339     0.499889        0.50025     0.0     1.926973
# min              104.780000     0.000000        0.00000  2016.0     1.000000
# ...

# %%
ad_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   datetime64[ns]
#  9   Clicked on Ad             1000 non-null   int64
#  10  Year                      1000 non-null   int64
#  11  Month                     1000 non-null   int64
#  12  Day                       1000 non-null   int64
# ...

# %%
ad_data.drop('Year',axis=1,inplace=True)

# %%
sns.pairplot(ad_data,hue='Clicked on Ad')

# %%
sns.jointplot(data=ad_data,x='Age',y='Area Income')

# %%
sns.jointplot(kind='kde',data=ad_data,x='Age',y='Daily Time Spent on Site')

# %%
sns.jointplot(data=ad_data,x='Daily Time Spent on Site',y='Daily Internet Usage')

# %%
# Check for missing data
sns.heatmap(ad_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
# each ad has a different Topic Line
#ad_data.groupby('Ad Topic Line').nunique()

# 31 repeated cities... not enought to catagorize by
# ad_data.groupby('City').nunique()

# 237 contries in the data set... still too many to create individual variables for
ad_data.groupby('Country').nunique()
# Out:
#                    Daily Time Spent on Site  Age  Area Income  \
# Country
# Afghanistan                               8    8            8
# Albania                                   7    6            7
# Algeria                                   6    6            6
# American Samoa                            5    5            5
# Andorra                                   2    2            2
# ...                                     ...  ...          ...
# Wallis and Futuna                         4    4            4
# Western Sahara                            7    6            7
# Yemen                                     3    3            3
# Zambia                                    4    4            4
# Zimbabwe                                  6    5            6
#
#                    Daily Internet Usage  Ad Topic Line  City  Male  Country  \
# Country
# Afghanistan                           8              8     8     2        1
# ...

# %%
ad_data.drop(['Ad Topic Line','City','Country','Timestamp','Time'],axis=1,inplace=True)
ad_data2 = ad_data.drop(['Month','Day'],axis=1) # for analysis without Day and month

# %%
ad_data
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                       68.95   35     61833.90                256.09     0
# 1                       80.23   31     68441.85                193.77     1
# 2                       69.47   26     59785.94                236.50     0
# 3                       74.15   29     54806.18                245.89     1
# 4                       68.37   35     73889.99                225.58     0
# ..                        ...  ...          ...                   ...   ...
# 995                     72.97   30     71384.57                208.58     1
# 996                     51.30   45     67782.17                134.42     1
# 997                     51.63   51     42415.72                120.37     1
# 998                     55.55   19     41920.79                187.95     0
# 999                     45.01   26     29875.80                178.35     0
#
#      Clicked on Ad  Month  Day
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = ad_data.drop(['Clicked on Ad'],axis=1)
y = ad_data['Clicked on Ad']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 290                     50.52   31     72270.88                171.62     0
# 167                     86.06   31     53767.12                219.72     1
# 486                     83.97   40     66291.67                158.42     1
# 683                     76.83   28     67990.84                192.81     0
# 876                     67.39   44     51257.26                107.19     0
# ..                        ...  ...          ...                   ...   ...
# 575                     48.86   54     53188.69                134.46     0
# 838                     44.13   40     33601.84                128.48     1
# 337                     75.32   28     59998.50                233.60     1
# 523                     67.94   43     68447.17                128.16     0
# 863                     76.64   39     66217.31                241.50     1
#
#      Month  Day
# 290      1   23
# 167      4   28
# ...

# %%
y_train
# Out:
# 290    1
# 167    0
# 486    0
# 683    0
# 876    1
#       ..
# 575    1
# 838    1
# 337    0
# 523    1
# 863    0
# Name: Clicked on Ad, Length: 700, dtype: int64

# %%
# Logistic Regression WITH Day and Month as variables

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression(max_iter=300)
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=300,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
coef_df = pd.DataFrame(logmodel.coef_.reshape(7,1),X_train.columns,columns=['Coef'])
coef_df
# Out:
#                               Coef
# Daily Time Spent on Site -0.061972
# Age                       0.223943
# Area Income              -0.000014
# Daily Internet Usage     -0.028983
# Male                     -0.004453
# Month                     0.340965
# Day                       0.053130

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
print()
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92       157
#            1       0.93      0.89      0.91       143
#
#     accuracy                           0.92       300
#    macro avg       0.92      0.92      0.92       300
# weighted avg       0.92      0.92      0.92       300
#
#
# [[148   9]
#  [ 16 127]]

# %%
# Logistic Regression WITHOUT any Date or Time Info

# %%
X2 = ad_data2.drop(['Clicked on Ad'],axis=1)
y2 = ad_data2['Clicked on Ad']

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.3, random_state=101)

# %%
X_train2
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male
# 290                     50.52   31     72270.88                171.62     0
# 167                     86.06   31     53767.12                219.72     1
# 486                     83.97   40     66291.67                158.42     1
# 683                     76.83   28     67990.84                192.81     0
# 876                     67.39   44     51257.26                107.19     0
# ..                        ...  ...          ...                   ...   ...
# 575                     48.86   54     53188.69                134.46     0
# 838                     44.13   40     33601.84                128.48     1
# 337                     75.32   28     59998.50                233.60     1
# 523                     67.94   43     68447.17                128.16     0
# 863                     76.64   39     66217.31                241.50     1
#
# [700 rows x 5 columns]

# %%
y_train2
# Out:
# 290    1
# 167    0
# 486    0
# 683    0
# 876    1
#       ..
# 575    1
# 838    1
# 337    0
# 523    1
# 863    0
# Name: Clicked on Ad, Length: 700, dtype: int64

# %%
logmodel2 = LogisticRegression(max_iter=300)
logmodel2.fit(X_train2,y_train2)

coef_df2 = pd.DataFrame(logmodel2.coef_.reshape(5,1),X_train2.columns,columns=['Coef'])
coef_df2
# Out:
#                               Coef
# Daily Time Spent on Site -0.051243
# Age                       0.236158
# Area Income              -0.000010
# Daily Internet Usage     -0.024683
# Male                      0.001077

# %%
predictions2 = logmodel2.predict(X_test2)
print(classification_report(y_test2,predictions2))
print()
print(confusion_matrix(y_test2,predictions2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       157
#            1       0.94      0.90      0.92       143
#
#     accuracy                           0.93       300
#    macro avg       0.93      0.93      0.93       300
# weighted avg       0.93      0.93      0.93       300
#
#
# [[149   8]
#  [ 14 129]]
